# %% [markdown]
# Group 7:
# Agojo, Nigel Oliver;
# Bagalso, Riana Alexis;
# Gabarda, Clark;
# Abocejo, Earl Ian

# %% [markdown]
# Importing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading

# %%
visitor = pd.read_csv('Visitor_Logs.csv', encoding = 'latin-1')
df = pd.DataFrame(data)

# %% [markdown]
# Analysis

# %%
statistics=visitor.describe()

# %% [markdown]
# Manipulation

# %%
freq_exhibits = df['Exhibit Visited'].value_counts()
df['Dare'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Visualization

# %%
freq_exhibits.plot(kind='bar')
plt.title('Frequency of visits on an Exhibit')
plt.xlabel('Exhibit')
plt.ylabel('Count', rotation=0)
plt.xticks(rotation=0)
plt.show()
